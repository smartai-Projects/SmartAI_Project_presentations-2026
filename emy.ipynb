# %% [markdown]
# # Emy on Google Colab with ollama
#
# This notebook:
# - installs Ollama
# - pulls a model
# - start up emy

# %%
# %%capture
# !apt-get update -y
# !apt-get install -y curl pciutils

# %%
# %%capture
# !sudo apt-get install zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
import os
import subprocess
import time
import signal

os.environ['OLLAMA_HOST'] = '0.0.0.0:11434'

log_file = '/tmp/ollama_server.log'
with open(log_file, 'w') as f:
    proc = subprocess.Popen(
        ['ollama', 'serve'],
        stdout=f,
        stderr=subprocess.STDOUT,
        preexec_fn=os.setsid
    )

print('Started ollama serve with PID:', proc.pid)
time.sleep(8)

with open(log_file, 'r') as f:
    print(f.read()[-4000:])
# Out:
# Started ollama serve with PID: 3201
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAICeptvxZNlOUXxymtqbJJRn5Sf04h2vYjvJkrkEOj+aQ
#
# ...

# %%
# !curl http://127.0.0.1:11434/api/tags
# Out:
# {"models":[]}

# %% [markdown]
# ## Pull a model
#
# You can change `MODEL_NAME` if you want a different Ollama model.

# %%
# !ollama pull qwen2.5:7b
# !ollama pull nomic-embed-text
# !ollama pull deepseek-r1:8b
# !ollama pull gemma3:12b

# %%
# !curl http://127.0.0.1:11434/api/tags
# Out:
# {"models":[{"name":"nomic-embed-text:latest","model":"nomic-embed-text:latest","modified_at":"2026-03-18T15:54:47.404871998Z","size":274302450,"digest":"0a109f422b47e3a30ba2b10eca18548e944e8a23073ee3f3e947efcf3c45e59f","details":{"parent_model":"","format":"gguf","family":"nomic-bert","families":["nomic-bert"],"parameter_size":"137M","quantization_level":"F16"}},{"name":"qwen2.5:7b","model":"qwen2.5:7b","modified_at":"2026-03-18T15:54:38.654070786Z","size":4683087332,"digest":"845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"7.6B","quantization_level":"Q4_K_M"}}]}

# %% [markdown]
# ## Emy setup

# %%
# !git clone -b research-runtime https://github.com/FallingObject/emy.git
# %cd emy
# !pip install -e .
# Out:
# Cloning into 'emy'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 86 (delta 35), reused 78 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 81.17 KiB | 735.00 KiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/emy
# Obtaining file:///content/emy
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 125.2 MB/s eta 0:00:00
# ...
#   Building editable for emy (pyproject.toml) ... done
#   Created wheel for emy: filename=emy-3.0.0-0.editable-py3-none-any.whl size=9830 sha256=5fc93092b8ebf7f100095e28d9dfd2082c60dbd85af3a2fe6beb0ff69301af24
# ...

# %%
# !python3 emy/gradio_app.py
# Out:
# /content/emy/emy/gradio_app.py:676: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chat = gr.Chatbot(label="Conversation", height=560, type="messages")
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://444976b393d3cd2996.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
